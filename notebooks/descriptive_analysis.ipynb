# %%
hh_fut = di.load("henry_hub_futures")
hh_spot = di.load("henry_hub_spot")
pjm_fut = di.load("pjm_peak_futures")
pjm_spot = di.load("pjm_western_hub_peak_spot")

table = descriptive_table_for_datasets({
    "Henry Hub Futures": hh_fut,
    "Henry Hub Spot": hh_spot,
    "PJM Futures": pjm_fut,
    "PJM Spot": pjm_spot,
})
